# %%
# %sql
CREATE CATALOG IF NOT EXISTS rideshare
MANAGED LOCATION 'abfss://basecontainer@rideshareadls.dfs.core.windows.net'

# %%
# %sql
USE CATALOG rideshare;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS rideshare.bronze
MANAGED LOCATION 'abfss://basecontainer@rideshareadls.dfs.core.windows.net/bronze'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS rideshare.silver
MANAGED LOCATION 'abfss://basecontainer@rideshareadls.dfs.core.windows.net/silver'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS rideshare.gold
MANAGED LOCATION 'abfss://basecontainer@rideshareadls.dfs.core.windows.net/gold'
